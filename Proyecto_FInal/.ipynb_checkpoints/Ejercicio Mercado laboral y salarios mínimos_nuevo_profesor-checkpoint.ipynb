# %% [markdown]
# # Modelo computacional para el análisis causal de políticas públicas
# #### (El caso de los salario mínimos en un mercado laboral acotado)
# ### por Gonzalo Castañeda
# #### CIDE, México (Otoño, 2022)

# %% [markdown]
# Propósito del modelo: mostrar las ventajas de los ABM en el estudio de las inferencias causales. A partir de esta metodología es posible construir un marco teórico que analice el impacto de ciertas intervenciones (políticas y programas) en las variables de interés.
# (i) Permite generar contrafactuales para el grupo de tratamiento que son proxys apropiadas para describir escenarios que pudieron haber ocurrido post-tratamiento si la intervención no hubiera ocurrido, lo que reduce la creación de sesgos en la medición de los impactos causales.
# (ii) La política se puede estudiar en contextos muy variados, e inclusive cuando no existe evidencia empírica sobre los efectos de la política a analizar, ya sea porque el entorno es otro, o bien porque las caracaterísticas específicas de las políticas ya implmentadas son diferentes.
# (iii) Muestra que los estudios causales basados exclusivamente en análisis econométricos pueden ser desafortunados cuando las conclusiones obtenidas son extrapoladas para su uso en contextos diferentes. Lo que apunta a las ventajas de complementar el análisis empírico con formulaciones teóricas rigurosas.
#
# A manera de ilustrar la metodología se construye un ABM sencillo sobre un mercado laboral de trabajadoras domésticas acotado a un espacio geográfico (e.g., cotos residenciales), cuyo propósito es estudiar el impacto que sobre el desempleo tiene un cambio en los salarios mínimos

# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt
from numpy.ma import masked_array

# %%
# Definición de parámetros
base = 50            # celdas (hogares) del coto residencial a estudiar
altura = 50
ocupacion = 0.2      # porcentaje de hogares que requieren trabajadoras (porcentaje de empleos máximo)
lazos = 3            # número de vínculos de amistad de las empleadas domésticas
sal_min = 3          # salario mínimo inicial

# %%
# Inicialización del coto y definición de las condiciones iniciales del mercado 
# laboral

def inicializar(coto):               # coto define la capacidad de pago de empleadores
    rd.seed(1234)                    # se establecen condiciones iniciales similares entre corridas        
    global mes, factibles, vacantes, salarios, sal_conv, ofertas, empleadas, des_temp
    empleadas = []                   # listado de trabajadoras domésticas
    amigas = []                      # listado de lazos de amistad de las empleadas del coto
    mes = 0
    des_temp = [0]                   # variable de resultados: número de desempleados (vacantes)
                                     # el coto se formula mediante una retícula cuadrada que en 
                                     # Python se describe con un arreglo de ceros en numpy
                                     # las condiciones de los empleadores son las siguientes:
    factibles = np.zeros([base, altura]) # cota máxima para el pago de salarios según ingreso familiar
    salarios = np.zeros([base, altura])  # salarios que cada hogar está dispuesto a pagar 
    sal_conv = np.zeros([base, altura])  # salarios convencionales producto de la influencia vecinal
    vacantes = np.zeros([base, altura])  # vacantes disponibles, 1 = plaza está ocupada
    ofertas = np.zeros([base, altura])   # ofertas laborales recibidas cuando la plaza estaba ocupada

#"""Definimos capacidad de pago de los hogares, salarios iniciales y plazos para vencimiento
#   de la relación contractual"""
                                      # exploramos el coto con un doble loop para asignar trabajadoras
                                      # en los hogares y establecer las condiciones iniciales
    for x in range(base):
        for y in range(altura):       # se inicia con salarios > minimo, pero < capacidad de pago
                                      
            #factibles[x, y] = rd.randint(20, 50)
            factibles[x, y] = rd.randint(coto, coto+30) 
                                                        # se define al azar el ingreso del empleador
                                                        # la capacidad de pago por  hogar es el  
                                                        # máximo salario posible a pagar    
          # en factibles ya se define un porcentaje del ingreso del empleador = capacidad a pagar
                                                        # Primero definimos salarios iniciales
            if coto == 20:                              # por debajo de factibilidad, de tal forma
                                                        # que todos pueden pagarlo al inicio
                salarios[x, y] = rd.randint(sal_min, (factibles[x, y]//4))
                
            else:                          # Aquí para hacer analisis de sensibilidad x factibilidad                      
                salarios[x, y] = rd.randint(sal_min, (coto+30)//4)   #Ojo algunos no pueden pagar
            if rd.random() < ocupacion:    # posicionamiento aleatorio de trabajadoras en el coto
                vacantes[x,y] = 1           # locación a la que se asigna la trabajadora
                plazos = rd.randint(0, 12)  # duración inicial del contrato con distintos plazos
                busquedas = 0               # búsquedas de empleo por la trabajadora
                
                empleadas.append([x, y, salarios[x,y], plazos, amigas, busquedas]) # listado en el que
                                            # se definen las características del trabajo: 
                                            # (0) coordenada x locación, (1) coordenada y, (2) salario
                                            # (3) plazo que resta, (4) lazos de amistad, 
                                            # (5) búsquedas de empleo realizadas una vez que termina
                                            # la relación laboral                                                                            

#"""Se define la red de amistad de cada una de las empleadas"""

                                            # se establece la red de amistad de las empledas 
    for i in range(0,len(empleadas)):       # se itera sobre el indice del vector de empleadas
        indice = list(range(0,len(empleadas)))
        indice.remove(i)                # se elimina a la propia empleada
        for j in range(0,lazos+1):      # c/u tiene igual número de lazos de amistad
            azar = rd.choice(indice)    # como choice hace muestreo con reemplazo, elegimos una x una
            indice.remove(azar)         # eliminamos del índice a la amiga elegida
            amigas.append(azar)         # se van incorporando al vector las amigas seleccionadas
        empleadas[i][4] = amigas      # vector se asigna al elemento de amistades de empleadas
        amigas = []           # se vacia el vector para iniciar otra iteración con diferente empleada

# %%
# En esta rutina se actualizan las iteraciones, lo que implica ajustar vacantes, 
# calcular salarios convencionales, reajustar salarios, realizar búsquedas, recibir ofertas 
# de empleadas y calcular nivel de desempleo 
                                                   
                                            # Intervención = se activa o no;
                                            # incr_sal = nivel del nuevo salario(alto, medio, bajo)
                                            # per_inter = mes de la intervención
                                            # ana_sen = parametro para sensibilidad de analísis
def actualizar(intervencion, incr_sal, per_inter, ana_sen):
    rd.seed()          # semilla aleatoria se elimina para que haya cambios al azar en etapa iterativa
    global mes, factibles, vacantes, salarios,  ofertas, empleadas, des_temp, sal_conv, sal_min
    if intervencion == 'activada' and mes == per_inter: # en caso de intervención activa y mes 
                                                        # indicado para aplicarla
        sal_min = intervenir(incr_sal, ana_sen)    # se aplica nuevo salario mínimo según nivel
    ind1 = []                               # listado para almacenar a empledas que mantienen contrato
    ind2 = []                               # listado para almacenar empleadas cuyo contrato vence
    rompen = []                             # listado para empleadas con rompimiento contractual
    vecinos = [-1, 0, 1]                    # distancia de los vecinos dx, dy
    
                                            # iteramos sobre las empleadas para checar su situación
                                            # laboral
#"""Clasificación de las trabajadoras en empleadas, desempleadas por vencimiento de contrato
#   o desempleadas por rompimiento de relaciones contractuales"""

    for i in range(0,len(empleadas)):
        if empleadas[i][3] > 0:
            empleadas[i][3] -= 1            # si contrato aún no vence se reduce el plazo en un mes
            ind1.append(i)                  # se incorpora a la lista de las que aún tienen contrato
        else:
            ind2.append(i)                  # empleadas con contrato vencido      
    s = ((base*altura*ocupacion)-des_temp[mes])*0.10   # de las gentes aún empleadas un porcentaje
                                            # rompe la relación laboral de manera idiosincrática
        
                                            # se elige al azar aquellas con contrato que terminan
                                            # su relación laboral de manera intempestiva
    for j in range(0,round(s)):
        azar = rd.choice(ind1)              # se toma del listado de las empleadas una al azar
        rompen.append(azar)                 # se incorpora su índice en un nuevo listado (rompen)
        ind1.remove(azar)                   # se elimina del listado de trabajadoras con empleo
    for i in rompen:                        # para las que rompieron con los empleadores
        empleadas[i][3] = 0                 # su contrato se finiquita y el plazo se ajusta a cero
                                            # busquedas se mantienen en 0, porque esta variable se
                                            # hace positiva cuando inicia la búsqueda de chambas
                                            # la posición de la empleda en un hogar se cambia después
                               
                                #En los hogares en que las trabajadoras quedaron desempleadas
                                #se abre un espacio laboral
    for i in rompen + ind2:      
        x = empleadas[i][0]       # se especifican sus coordenadas del empleo previo
        y = empleadas[i][1]
        vacantes[x,y] = 0         # deja de haber empleada en el hogar(x,y) 
        


#"""Definición de salarios a partir de información local (salarios previos de vecinas), 
#   tomando en cuenta que son factible y ajustando por la incidencia de la oferta laboral;
#   solo se ajustan ofrecimientos salariales de las que quedaron desempleadas"""
                    
    ant_sal = salarios.copy()        # los salarios existentes se copian en un nuevo arreglo para
                                     # actualizar los salarios convencionales y pagados


    for x in range(base):          # todos los hogares, tengan empleadas o no pueden modificar
        for y in range(altura):    # sus percepciones sobre los salarios que pueden pagar
            if rd.random() < 0.05:  # este proceso se hace solo para el %5 de los hogares p/periodo
                #sal_conv[x,y] = 0    #este comando lo usaría si no quiere acumular sal_conv anterior
                for dx in range(-1, 2):     #checamos la vecindad             
                    for dy in range(-1, 2):    # notar que se emplean fronteras periódicas                         
                        sal_conv[x,y] += ant_sal[(x + dx) % base, (y+dy) % altura]
                sal_conv[x,y] = sal_conv[x,y]/9      # se calcula el salario convencional
                                                     # Ojo: de acuerdo a esta fórmula estamos
                #sumando el salario convencional en t-1 de (x,y) a los salarios pagados de los 9 
                #vecinos también en t-1 (incluye el de la celda central). No dividimos entre 10
                #ya que ello haría que el salario mínimo fuera mayor en cada periodo por la forma
                #en que generamos los datos en las condiciones iniciales 
               
                                                     # los salarios convencionales se ajustan a la
                                                     # baja con el número de solicitudes de empleo;
                                                     # se pagan los convencionales si son más
                                                     # elevados que el mínimo
                salarios[x,y] = max(sal_min , (1 - ofertas[x,y]/12)*sal_conv[x,y])
                
                # si los salarios convencionales ajustados son muy altos, a lo más pagan el mínimo
                if (1 - ofertas[x,y]/12)*sal_conv[x,y] > factibles[x,y]: 
                    salarios[x,y] = sal_min
                            
    
    
#"""Inicio de búsqueda de empleo de las trabajadoras que quedaron sin chamba """        
        
                                    # el siguiente paso es iniciar la búsqueda de empleo
                                    # se inicia intentando renovar cuando la terminación 
                                    # del contrato no fue por ruptura.
    rd.shuffle(ind2)                # para evitar artefactos se aleatorizan los índices de empleadas
    ind2_bis = ind2.copy()          # se crea una copia del listado de empleadas con contrato vencido 
                                    # ya que ind2 se va a modificar en iteración
    for i in ind2_bis:              # Se itera solo sobre este tipo de desempleadas
        corte = False
        x = empleadas[i][0]         # se especifican sus coordenadas
        y = empleadas[i][1]
                                    # si salarios nuevos son mayores o iguales a los anteriores 
                                    # pero no rebasan los factible se establece el convenio laboral
                                    # suponemos que hogares nunca pagan por debajo de salario
                                    # mínimo ¿será?
                        
#"""1a opción: se busca reactivar la relación laboral en el propio hogar donde terminó el plazo """

        if (salarios[x,y] >= ant_sal[x,y]) and (salarios[x,y] <= factibles[x,y]):
            vacantes[x,y] = 1       # se ocupa a la empleada
            empleadas[i][2] = salarios[x,y]  #se asigna nuevo salario a base de datos de empleada
            empleadas[i][3] = 12    # reinicia el plazo del contrato            
            ofertas[x,y] = 0        # una vez con contrato se elimina registro de solicitudes
            ind2.remove(i)          # se remueve de la lista de desempleados
            
                                    # en caso de no llegar a un acuerdo se busca la chamba entre los
                                    # vecinos del antiguo empleador
                    
#"""2a opción: se busca encontrar trabajo entre los vecions del hogar en donde previamente 
#   se laboró, pero no se pudo dar la rennovación contractual"""

        else:
            rd.shuffle(vecinos)     # se aleatorizan las distancias de los vecinos
            for dx in vecinos:
                if corte:
                    break           # para detener búsqueda en caso de encontrar empleo (ver abajo)
                for dy in vecinos:  # se toma de nueva cuenta fronteras periodicas
                                    # si salario ofrecido es mejor a anterior, el lugar está
                                    # disponible y los salarios no son excesivos
                                    # se establece un nuevo contrato
                        if dx == 0 and dy == 0:    # no incluimos al hogar en donde trabajaba antes
                            pass
                        else:
                            if (salarios[(x + dx) % base, (y+dy) % altura] >= ant_sal[x,y]) \
                                and (vacantes[(x + dx) % base, (y+dy) % altura] == 0) \
                                and (salarios[(x + dx) % base, (y+dy) % altura] <= \
                                factibles[(x + dx) % base, (y+dy) % altura]):
                                vacantes[(x + dx) % base,(y + dy) % altura] = 1 #se ocupa al empleado
                                empleadas[i][0] = (x + dx) % base   # se especifica su nueva locación
                                empleadas[i][1] = (y + dy) % altura
                                empleadas[i][2] = salarios[(x + dx) % base, (y+dy) % altura] #nuevo salario
                                empleadas[i][3] = 12                 # se reinicia el plazo
                                ofertas[(x + dx) % base, (y+dy) % altura] = 0   # se elimina registro 
                                ind2.remove(i)           # se elimina trabajador de lista de desempleaod
                                corte = True             # se interrumpe busqueda
                                break
                            else:                        
                                                     # en caso de no llegar a un convenio, el hogar lo
                                                     # registra como una solicitud laboral
                                                     # notar que no se registra por parte del empleado
                                                     # como búsqueda ya que ello ocurre solo afuera de 
                                                     # la vecindad
                                ofertas[(x + dx) % base,(y + dy) % altura] += 1

#"""3a opción: para las que todavía no encuentran trabajo (sea por vencimiento de contrato
#   o por rompimiento) se busca chamba, con la información que aportan las amigas, entre
#   los vecinos de donde estas últimas trabajan"""
 
                                # ahora iteramos sobre todos los desempleados que aún no se colocan
                                 # independientemente de si rompieron o terminó el plazo del contrato
    ind3 = ind2 + rompen
    rd.shuffle(ind3)             # aleatorizamos la busqueda
    ind3_bis = ind3.copy()       # como ind3 lo vamos a estar cambiando en iteración hacemos una copia
    for i in ind3_bis:           # realizamos la búsqueda para cada empleado
        corte = False
        x = empleadas[i][0]      # a partir del índice especificamos sus coordenadas    
        y = empleadas[i][1]
        amigas = empleadas[i][4] # tambien se especifica al vector de amigas        
        rd.shuffle(amigas)       # se aleatorizan a las amigas
        for j in amigas:
            if empleadas[j][3] != 0:     # si la amiga todavía trabaja puede dar información de chambas
                w = empleadas[j][0]      # queremos sondear la vecindad de la amiga
                z = empleadas[j][1]
                for dw in vecinos:       # se inicia proceso de búsqueda en su vecindad
                    if corte:
                        break            # para interrumpir búsqueda
                    for dz in vecinos:
                                         # se consideran fronteras periódicas; si el nuevo salarios
                                         # es mejor, si hay vacantes disponibles y si el salario no
                                         # es excesivo se establece el convenio
                        if dw == 0 and dz == 0:   #no incluimos al hogar en donde esta la amiga
                            pass
                        else:
                            if (salarios[(w + dw) % base, (z + dz) % altura] >= ant_sal[x,y]) \
                                and (vacantes[(w + dw) % base, (z+dz) % altura] == 0)  \
                                and (salarios[(w + dw) % base, (z + dz) % altura] <= 
                                factibles[(w + dw) % base, (z + dz) % altura]):
                                vacantes[(w + dw) % base, (z + dz) % altura] = 1    # se ocupa el trabajo
                                empleadas[i][0] = (w + dw) % base           # se definen nuevas coordenadas
                                empleadas[i][1] = (z + dz) % altura
                                empleadas[i][2] = salarios[(w + dw) % base, (z + dz) % altura]
                                empleadas[i][3] = 12                        # se establece nuevo plazo
                                ofertas[(w + dw) % base, (z + dz) % altura] = 0   # se elimina registro 
                                corte = True                                # se interrumpe la búsqueda
                                break
                            else:                  # de no acordar se registra nueva solicitud de empleo
                                ofertas[(w + dw) % base,(z + dz) % altura] += 1
        if corte:
            ind3.remove(i)    # se elimina a la empleada de lista de desempleadas 

#"""4a opción: las trabajadoras que aún no logran colocarse a partir de recomendaciones, buscan
#   chamba en hogares tomados al azar un cierto número de periodos exigiendo salarios atractivos;
#   cuando pasa este periodo deciden aceptar la oferta aún si los salarios son menores"""
    
                                        # por último, se inicia una búsqueda al azar en el coto
                                        # solo una por mes y en hogares fuera de la vecindad
    ind3_bis = ind3.copy()       # como ind3 lo vamos a estar cambiando en iteración hacemos una copia
    for i in ind3_bis:                  # sondeamos a todas las desempleadas que quedan
        x = rd.randint(0,base-1)        # escogemos un hogar al azar
        y = rd.randint(0,altura-1)
        u = empleadas[i][0]             # especificamos las coordenadas del trabajo anterior
        v = empleadas[i][1]
        vinculos_loc = []               # listado para guardar coordenadas de vecinos originales
        for s in range((u-1) % base, (u+2) % base):         # sondemaos la vecindad actual completa 
            for t in range((v-1) % altura, (v+2) % altura):       
                vinculos_loc.append((s,t))                  # guardamos las coordenadas de vecindad  
        while (x, y) in vinculos_loc:    # si cordenadas al azar coinciden con vecindad iteramos
            x = rd.randint(0,base-1)
            y = rd.randint(0,altura-1)

        if empleadas[i][5] < 4:         # checamos que no se haya excedido en búsquedas
                                        # y a partir de ello definimos el criterio para
                                        # llegar a un acuerdo
                                        # que haya vacantes, mejores salarios, pero no excesivos
                        
            criterio = (vacantes[x,y] == 0) and (salarios[x,y] >= ant_sal[u,v]) \
            and (salarios[x,y] <= factibles[x,y])
                                        # el criterio cambia cuando ya lleva tiempo buscando
                                        # ahora solo se requiere que haya vacantes y salario
                                        # no sea excesivo; es decir, la trabajadora acepta cualquier
                                        # salario ofrecido
        else:
            criterio = (vacantes[x,y] == 0) and (salarios[x,y] <= factibles[x,y])
                                       # si el criterio se cumple se acepta un contrato y se ajusta
                                       # información laboral
            if criterio:
                vacantes[x,y] = 1      # se ocupa el trabajo
                empleadas[i][0] = x    # se asignan el hogar elegido al azar como nuevo trabajo
                empleadas[i][1] = y
                empleadas[i][2] = salarios[x,y]
                empleadas[i][3] = 12   # se reestablece plazo del contrato
                empleadas[i][5] = 0    # se reinician búsquedas
                ofertas[x,y] = 0       # se elimina registro de solicitudes
                ind3.remove(i)         # se elimina de la lista de desempleadas
                
                                       # de no llegar a un convenio
            else:
                ofertas[x,y] += 1      # se incrementan las solicitudes laborales
                empleadas[i][5] += 1   # aumentan las búsquedas realizadas
        
    mes += 1                           # se actualiza el periodo de iteración (mes)
    des_temp.append(len(ind3))         # se actualiza listado con desempleo temporal (por mes)

# %%
# En esta rutina se define el monto del incremento salarial que se aplica cuando hay intervención 

def intervenir(incr_sal, ana_sen):   # incr_sal define el tipo de incremento entre bajo, medio y alto
    global factibles, sal_conv
    mean_conv = sal_conv[vacantes == 1].mean()  # se toma la media de los salarios convencionale
                                                # pero solo de los hogares que tienen empleada
    if incr_sal == 'marginal':
        sal_min = mean_conv*0.9 
    elif incr_sal == 'bajo':                    # para los cuatro casos (marginal, bajo, medio, alto) 
        sal_min = mean_conv*1.5                 # el mínimo es una proporción del salario convencional
    elif incr_sal == 'medio':                   # promedio
        sal_min = mean_conv*6
    else:                                                    
        sal_min = mean_conv*10

    print('Salario mínimo post-intervención =', sal_min)
    return sal_min                              # como el sal_min no se define como variable global

# %%
# En esta rutina el propósito es mostrar los hogares en los que si hay trabajo domestico en un
# tiempo  dado
def observar_vacantes():
    global vacantes, mes                                        
    plt.imshow(vacantes, vmin = 0, vmax = 1, cmap = 'cool') # Se transforman dígitos en imágenes
    plt.title('mes = ' + str(mes))                 # Se especifica el mes de la iteración
    plt.show()

# %%
# En esta rutina el propósito es mostrar los condiciones salariales
def observar_salarios(sal_min):
    global salarios, mes, vacantes
    for x in range(base):
        for y in range(altura):
            if vacantes[x,y] == 0:
                sal_corr[x,y] = -1      # en donde no hay trabajo asignamos un valor negativo
            else:
                sal_corr[x,y] = salarios[x,y]   # si hay trabajo ponemos el salario pagado
            
        # Creamos dos plantillas para poder distinguir hogares en los que hay y no hay empleo
        # en los que no hay empleo no se considera su salario
    si_trab = masked_array(sal_corr, sal_corr <= 0) #se eliminan los hogares en que no hay trabajadoras 
    no_trab = masked_array(sal_corr, sal_corr > 0)  #se eliminan los hogares en las que haytrabajadoras

    
    fig, ax = plt.subplots()             #necesitamos esto pues vamos a encimar dos retículas
    shw1 = ax.imshow(si_trab,  cmap=plt.cm.Greens )
    shw2 = ax.imshow(no_trab,  cmap=plt.cm.Reds)

    bar1 = plt.colorbar(shw1)   
    bar2 = plt.colorbar(shw2)

    bar1.remove()                   #eliminamos la barra de tonos de colores
    bar2.remove()
    plt.title('mes = ' + str(mes))  # Se especifica el mes de la iteración
    plt.show()

# %%
# En esta rutina se establece una simulación invocando funciones de inicializar y actualizar, en la 
# que se especifican como argumentos número de periodos, si hay intervención (activa), su magnitud,
# mes de la intervención y si hay análisis de sensibilidad con salaarios mínimos

def simular(iteraciones, intervencion, incr_sal, per_inter, coto, ana_sen):
    global des_temp
    inicializar(coto)
    for i in range (0, iteraciones+1):
        actualizar(intervencion, incr_sal, per_inter, ana_sen)

# %%
# Con esta rutina se analiza lo que pasaría si el modelo se corre a partir de las condiciones 
# iniciales sin incorporar un periodo de transición; además se analiza el impacto que pueden 
# tener en los salarios promedios pagados al momento de darse un incremento en salarios mínimos

inicializar(coto=20)
salar_med = []                    # listado para guardar salarios medios en el tiempo
iniciales = 240                   # se deja correr un tiempo para compensar por condiciones iniciales
per_inter = 360                   # mes de la intervención  
total = per_inter + 120           # tiempo final de la corrida
for j in range(0,total):
    actualizar('activada', 'marginal', per_inter, ana_sen=0)       # argumentos  para actualizar 
    salar_med.append(salarios[vacantes == 1].mean())    # se calculan salarios medio en hogares que
                                                        # tienen empleadas domésticas
                                                        # y se incorporan a la serie de tiempo

                                        # preparamos información para la gráfica de salarios
sal_med_obs = salar_med[1:total]        # la serie de tiempo a graficar tiene la misma extensión
plt.plot(sal_med_obs, label = "promedios mensuales")
plt.axvline(x = per_inter, color = 'r', linestyle='dashed', label = 'mes de la intervención')
plt.xlabel('Tiempo')
plt.ylabel('Salarios')
plt.suptitle("Dinámica del salario pagado")
plt.title('(con intervención)')
plt.legend()
plt.show()
# Out:
# Salario mínimo post-intervención = 3.1518724963809097

# %% [markdown]
# Explicación (1): Debido al proceso de generación de salarios en la rutina inicializar() algunos hogares  empiezan ofreciendo salarios muy por encima de los mínimos, ya que sus capacidades económicas se lo permiten. Sin embargo, conforme pasan los meses y la gente se vuelve desocupada por terminación de contrato o ruptura, tienen que recontratarse. Estas trabajadoras tienen dificultades para encontrar salarios tan altos, por lo que a la postre tienen que aceptar salarios más bajos, ya sea porque han pasado varios meses desempleadas o porque el incremento en solicitudes de empleo hace que los empleadores ya no están dispuestos a pagar salarios tan altos.
# Notar que con el tiempo el criterio de salarios convencionales lleva a una norma salarial ligeramente por encima del salario mínimo. Este resultado implica que para las simuaciones es conveniente dejar un periodo de transición hasta que la norma salarial se consolide.
#
# Explicación (2): Al darse un incremento exógeno en los salarios mínimos, los salarios pagados repuntan ya que aquellos hogares que estaban pagando un salarios mínimo, que en su vecindad estaba por encima del convencional, se ven obligados a acatar la disposición legal y, por ello, los trabajadores recién contratados reciben mayores salarios. A su vez este incremento en salarios mínimos impulsa a la alza la norma salarial.

# %%
# Con esta rutina se hace una prueba del modelo y se checa la dinamica de los salarios pagados
# ya sea con intervencion o sin ella; se puede checar como un aumento en salarios mínimos incrementa
# los salarios promedios en general
# Cabe también notar que a lo largo del tiempo hay fluctuaciones en los salarios, inclusive sin
# intervención por efecto de las renuncias y la finalización de contratos

sal_min = 3
inicializar(coto=20)
salar_med = []                    # listado para guardar salarios medios en el tiempo
iniciales = 240                   # se deja correr un tiempo para compensar por condiciones iniciales
per_inter = iniciales + 120 + 1   # mes de la intervención
total = per_inter + 120           # tiempo final de la corrida
for j in range(0,total):
    actualizar('activada', 'marginal', per_inter, ana_sen=0)     # argumentos  para actualizar 
    salar_med.append(salarios[vacantes == 1].mean())    # se calculan salarios medio en hogares que
                                                        # tienen empleadas domésticas
                                                        # y se incorporan a la serie de tiempo

                                  # preparamos información para la gráfica de salarios
sal_med_obs = salar_med[iniciales+1:total]   # la serie de tiempo a graficar tiene la misma extensión
plt.plot(sal_med_obs, label = "promedios mensuales")
plt.axvline(x = 120, color = 'r', linestyle='dashed', label = 'mes de la intervención')
plt.xlabel('Tiempo')
plt.ylabel('Salarios')
plt.suptitle("Dinámica del salario pagado")
plt.title('(con intervención)')
plt.legend()
plt.show()
# Out:
# Salario mínimo post-intervención = 3.122747186760091

# %% [markdown]
# Esta figura ilustra que aunque no existan intervenciones si hay una dinámica de corto plazo
# para los salarios, por lo que pueden subir y bajar en el tiempo. Cuando se da la intervención se
# produce un ajuste rápido y la determinación de una nueva norma salarial

# %%
# En esta rutina mostramos el estado laboral al inicio de la corrida (después de que el sistema
# se ha estabilizado, unos meses antes de la intervención y unos meses despúes de la intervención
sal_min = 3
inicializar(coto=20)
iniciales = 240                   # se deja correr un tiempo para compensar por condiciones iniciales
per_inter = iniciales + 120 + 1   # mes de la intervención
total = per_inter + 120           # tiempo final de la corrida
for j in range(0,total):
    actualizar('activada', 'alto', per_inter, ana_sen=0)
    if mes == 241:
        print('Situación laboral al inicio de la corrida')
        observar_vacantes()
    elif mes == 300:
        print('Situación laboral en periodo pretratamiento')
        observar_vacantes()
    elif mes == 480:
        print('Situación laboral en periodo postratamiento')
        observar_vacantes()
    else:
        pass
# Out:
# Situación laboral al inicio de la corrida
# Situación laboral en periodo pretratamiento
# Salario mínimo post-intervención = 2.4231229600623414
# Situación laboral en periodo postratamiento

# %% [markdown]
# Observación: las celdas en blanco muestran lo hogares en los que no se contrata trabajadora alguna,
# mientras que los hogares verdes muestran hogares empleando trabajadoras domésticas.
# Al comparar el periodo inicial pre-intrevención con el final postintervención se observa que
# aumenta el desempleo (más celdas en blanco), lo que no se explica necesariamente por el aumento en salarios mínimos. Tendríamos que checar que la dinámica del modelo no tiende a generar un
# mayor desempleo en el transcurso del tiempo, aunque no haya intervención

# %%
# En esta rutina mostramos el estado de los salarios pagados en distintos meses de la corrida 

sal_min = 3
inicializar(coto=20)
iniciales = 240                   # se deja correr un tiempo para compensar por condiciones iniciales
per_inter = iniciales + 120 + 1   # mes de la intervención
total = per_inter + 120           # tiempo final de la corrida
for j in range(0,total):
    actualizar('activada', 'alto', per_inter, ana_sen=0)
    if mes == 241:
        print('Situación laboral al inicio de la corrida')
        observar_salarios(sal_min)
    elif mes == 300:
        print('Situación laboral en periodo pretratamiento')
        observar_salarios(sal_min)
    elif mes == 480:
        print('Situación laboral en periodo postratamiento')
        observar_salarios(sal_min)
    else:
        pass
# Out:
# Situación laboral al inicio de la corrida
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0161f93add7e> in <module>
#      10     if mes == 241:
#      11         print('Situación laboral al inicio de la corrida')
# ---> 12         observar_salarios(sal_min)
#      13     elif mes == 300:
#      14         print('Situación laboral en periodo pretratamiento')
#
# <ipython-input-7-72256e26adba> in observar_salarios(sal_min)
#       5         for y in range(altura):
#       6             if vacantes[x,y] == 0:
# ----> 7                 sal_corr[x,y] = -1      # en donde no hay trabajo asignamos un valor negativo
#       8             else:
#       9                 sal_corr[x,y] = salarios[x,y]   # si hay trabajo ponemos el salario pagado
#
# NameError: name 'sal_corr' is not defined

# %% [markdown]
# Observación 1: en naranja se presentan a los hogares que no emplean trabajadoras domésticas;
# en blanco se muestran a las trabajadoras que reciben el salario mínimo, mientras que en tonos de
# verdes de muestra el salario pagado (> al mínimo) en hogares con trabajadoras; entre mayor es el tono mayor es el salario.
# Observación 2: En el mes de postintervención, hay mas hogares (celdas) en naranja, lo que implica un
# mayor nivel de desempleo --ojo no necesariamente causado por el aumento en salarios mínimos-- Notar también que, producto de la interacción social, los clusters de desempleo están mas fragmentados

# %%
# Con esta rutina se muestra que el impacto en los salarios importante no proviene de la dinámica 
# mes a mes, sino más bién de la intervención en salarios mínimos. Cuando este cambio no es tan 
# marginal las fluctuaciones mensuales son de sengundo orden de importancia en relación al
# impacto del cambio exógeno
# Notar que la nueva norma salarial no queda muy por encima de los salarios mínimos, por lo que
# uno pensaría que los salarios mínimos ejercen un efecto farol (o de guía)

sal_min = 3
inicializar(coto=20)
salar_med = []                    # listado para guardar salarios medios en el tiempo
iniciales = 240                   # se deja correr un tiempo para compensar por condiciones iniciales
per_inter = iniciales + 120 + 1   # mes de la intervención
total = per_inter + 120           # tiempo final de la corrida
for j in range(0,total):
    actualizar('activada', 'bajo', per_inter, ana_sen=0)  # argumentos  para actualizar 
    salar_med.append(salarios[vacantes == 1].mean())    # se calculan salarios medio en hogares que
                                                        # tienen empleadas domésticas
                                                        # y se incorporan a la serie de tiempo

                                  # preparamos información para la gráfica de salarios
sal_med_obs = salar_med[iniciales+1:total]   # la serie de tiempo a graficar tiene la misma extensión
plt.plot(sal_med_obs, label = "promedios mensuales")
plt.axvline(x = 120, color = 'r', linestyle='dashed', label = 'mes de la intervención')
plt.xlabel('Tiempo')
plt.ylabel('Salarios')
plt.suptitle("Dinámica del salario pagado")
plt.title('(con intervención)')
plt.legend()
# Out:
# Salario mínimo post-intervención = 5.178429157759723

# %%
# En esta rutina se compara la dinámica de los salarios pagados, salarios convencionales y mínimos
# con el propósito de identificar el impacto de una alza marginal en salarios mínimos
# (i.e, por debajo de convencionales)

sal_min = 3
inicializar(coto=20)
salar_med = []                    # listado para guardar salarios medios en el tiempo
conv_med = []
iniciales = 240                   # se deja correr un tiempo para compensar por condiciones iniciales
per_inter = iniciales + 120 + 1   # mes de la intervención
total = per_inter + 120           # tiempo final de la corrida
for j in range(0,total):
    actualizar('activada', 'marginal', per_inter, ana_sen=0)           # argumentos  para actualizar 
    salar_med.append(salarios[vacantes == 1].mean())    # se calculan salarios medio y convencionales
    conv_med.append(sal_conv[vacantes == 1].mean())     # en hogares que tienen empleadas domésticas
                                                        # y se incorporan a la serie de tiempo

                                  # preparamos información para la gráfica de salarios

sal_med_obs = salar_med[iniciales+1:total]   # la serie de tiempo a graficar tiene la misma extensión
conv_med_obs = conv_med[iniciales+1:total]
sal_min_obs= []
for i in range(iniciales+1 , total):
    if i <= per_inter:
        sal_min_obs.append(3)
    else:
        sal_min_obs.append(sal_min)
plt.plot(sal_med_obs, label = "salarios pagados")
plt.plot(conv_med_obs, label = "salarios convencionales")
plt.plot(sal_min_obs, label = "salarios mínimos")
plt.axvline(x = 120, color = 'r', linestyle='dashed', label = 'mes de la intervención')
plt.xlabel('Tiempo')
plt.ylabel('Salarios')
plt.suptitle("Dinámica del salario mensuales promedio")
plt.title('(con intervención)')
plt.legend()
# Out:
# Salario mínimo post-intervención = 3.1116050326107447

# %% [markdown]
# Explicación (1): En el periodo pre-intervención, un primer grupo de hogares paga un salario convencional alto (los menos), mientras que un segundo grupo paga un salario mínimo o salarios convencionales muy bajos, por lo que el salario pagado se encuentra entre los dos, pero más cercano a la línea de salarios mínimos.
#
# Explicación (2): En el periodo post-intervención, los salarios mínimos aumentan y con ello impulsan a la alza la norma salarial. Esto puede dislocar el mercado laboral (aumentar el desempleo) en la medida en que un mayor número de trabajadoras al terminar su contrato o renunciar deciden esperar más tiempo para tomar un empleo. En otras palabras, el alza marginal de salarios mínimos queda por debajo de los convencionales pre-interveción, lo que provoca un escenario en el que las ofertas salariales propuestas en muchos hogares con vacantes queden por debajo del salario previo de los que buscan empleo, lo que lleva a incrementar el tiempo de desocupación.

# %%
# En esta rutina se compara la dinámica de los salarios pagados, salarios convencionales y mínimos
# con el propósito de identificar el impacto de un aumento en salarios mínimos 'bajo', en vex de 
# marginal
# (i.e, por arriba de los salarios convencionales pre-intervención, pero aún lo suficientemente
# bajos como para no exceder la capacidad de pago de los hogares)

sal_min = 3
inicializar(coto=20)
salar_med = []                    # listado para guardar salarios medios en el tiempo
conv_med = []
iniciales = 240                   # se deja correr un tiempo para compensar por condiciones iniciales
per_inter = iniciales + 120 + 1   # mes de la intervención
total = per_inter + 120           # tiempo final de la corrida
for j in range(0,total):
    actualizar('activada', 'bajo', per_inter, ana_sen=0)           # argumentos  para actualizar 
    salar_med.append(salarios[vacantes == 1].mean())    # se calculan salarios medio y convencionales
    conv_med.append(sal_conv[vacantes == 1].mean())     # en hogares que tienen empleadas domésticas
                                                        # y se incorporan a la serie de tiempo

                                  # preparamos información para la gráfica de salarios
sal_med_obs = salar_med[iniciales+1:total]   # la serie de tiempo a graficar tiene la misma extensión
conv_med_obs = conv_med[iniciales+1:total]
sal_min_obs= []
for i in range(iniciales+1 , total):
    if i <= per_inter:
        sal_min_obs.append(3)
    else:
        sal_min_obs.append(sal_min)
plt.plot(sal_med_obs, label = "salarios pagados")
plt.plot(conv_med_obs, label = "salarios convencionales")
plt.plot(sal_min_obs, label = "salarios mínimos")
plt.axvline(x = 120, color = 'r', linestyle='dashed', label = 'mes de la intervención')
plt.xlabel('Tiempo')
plt.ylabel('Salarios')
plt.suptitle("Dinámica del salario mensuales promedio")
plt.title('(con intervención)')
plt.legend()
# Out:
# Salario mínimo post-intervención = 5.190655216208053

# %% [markdown]
# Explicación: Con salarios bajos (i.e., que no exceden la capacidad de pago de los hogares), no solo
# se produce un efecto disruptivo en la norma salarial, sino también salarios pagados que exceden
# a los convencionales temporalmente, lo que produce gran interés de los trabajadores a conseguir empleo de inmediato y, de esta, manera se puede producir una disminución en la tasa de desocupación, como se verá más adelante.

# %%
# En esta rutina se hace una corrida a manera de ejemplo, la que corre (después del periodo de 
# depuración) 120 meses pre-intervención y 120 meses post-intervención
# Se aplica solamente la Diferencia post-intervención para calcular el impacto que 
# tiene un aumento en el salario mínimo sobre el desempleo

sal_min = 3                     # se tiene que volver a especificar el sal_min por si hubo corrida
                                # previa en la que se modificaron
iniciales = 240
per_inter = iniciales + 120 + 1
total = per_inter + 120
simular(total, 'no_activada', 'bajo', per_inter, coto=20, ana_sen=0)  # en esta corrida no hay intervención
des_temp_noact = des_temp               # listado con datos de desempleo para serie contrafactual
                                        # es decir, sin la intervención
simular(total, 'activada', 'bajo', per_inter, coto=20, ana_sen=0)  # en esta corrida si hay intervención   
des_temp_act = des_temp                 # listado con datos de desempleo c/intervención      
dif_post_int = []                       # Listado para diferencias con datos de c/mes
                                        # en el periodo post-intervención
for item1, item2 in zip(des_temp_act[per_inter:total], des_temp_noact[per_inter:total]):
        item = item1 - item2
        dif_post_int.append(item)      # se van agregando diferencias en pre-intervención
                                       # se imprimen datos de las primeras diferencias:
print('Media de la diferencia de desocupación post-intervención =', np.mean(dif_post_int))
# Out:
# Salario mínimo post-intervención = 5.201811051614333
# Media de la diferencia de desocupación post-intervención = -6.066666666666666

# %%
# Rutina de graficación para ilustrar el impacto que tiene la intervención sobre el desempleo
# a través del tiempo, y se hace una comparación con el contrafactual (sin intervención)


des_temp_act_obs= des_temp_act[iniciales+1:total]     # serie de desempleo con intervención
des_temp_noact_obs= des_temp_noact[iniciales+1:total] # serie de desempleo sin intervención
plt.plot(des_temp_act_obs, label = "con aumento salarial")
plt.plot(des_temp_noact_obs, label = "sin intervención")
plt.axvline(x = 121, color = 'b', linestyle='dashed', label = 'mes de la intervención')
plt.xlabel('Tiempo')
plt.ylabel('Desempleo')
plt.title('(cálculos a partir de datos observados: tratamiento')
plt.suptitle('Impacto el el desempleo a partir de un aumento salarial')
plt.legend()
plt.show()

# %% [markdown]
# Observación 1: Notar que en el momento de la intervención (línea vertical azul), hay un desplome en
# la magnitud del desempleo (serie azul= intervenida), auque este va aumentando conforme pasa el tiempo.
# Observación 2: Para el cálculo del impacto se compara la serie intervenida con la no intervenida
# (línea color naranja). Se observa que una caida en el desempleo muy evidente en el corto y
# mediano plazo

# %%
# Rutina de graficación de histogramas traslapados para ilustrar 
# las distribuciones temporales del desempleo en series intervenida y contrafactual

des_post_act = des_temp_act[per_inter:total]       # datos artificiales en periodo post-intervención
des_post_noact = des_temp_noact[per_inter:total]
plt.hist(des_post_act, bins=20, edgecolor='black', alpha = 0.5, label = 'con aumento salarial')
plt.hist(des_post_noact, bins=20, edgecolor='black', alpha = 0.5, label = 'sin intervención')
plt.xlabel('Número de desempleados')
plt.ylabel('Frecuencia')
plt.title("(periodo post-intervención, tratamiento vs control)")
plt.suptitle("Impacto de un aumento salarial en el desempleo")
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# Al graficar las frecuencias del número de los desempleados de cada mes, se observa que la serie
# de datos de desempleo sin intervención da lugar a un histograma (color naranja) que tiende a
# generar datos de desempleo mayores a los que se observan en el histograma de datos con intervención
# (barras de color azul), lo que implica que en muchos más meses el desempleo cae cuando se produce
# un incremento en salarios mínimos

# %%
# Histograma que muestra datos mensuales de las diferencias en desempleo después de la 
# intervención (i.e., con respecto al contrafactual)

plt.hist(dif_post_int, bins=20, edgecolor='black', alpha = 0.5, label = 'Después de aumento salarial')
plt.xlabel('Valor excedente del desempleo')
plt.ylabel('Frecuencia')
plt.title("(en relación al contrafactual)")
plt.suptitle("Impacto de un aumento salarial en el desempleo")
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# En el hstograma se calculan las frecuencias de la diferencia en los niveles de desempleo de cada mes.
# Un valor negativo indica que el desempleo se redujo con la intervención en el periodo postratamiento.
# El heho de que sean mucho más comunes los meses con un valor negativo indica que en geneal el
# incremento en salarios mínimos produjo un impacto favorable en el empleo

# %%
# Se corre la simulación sin intervención para ilustrar la dinámica del desempleo
# Pudiera darse el caso de que el desempleo creciera (o decreciera) sin necesidad de
# que se produzca una intervención. No obstante, ello no implicaría que sea necesario aplicar un DiD
# en el que una primera diferencia inter-temporal elimina efectos fijos
# Esto se debe a que el contrafactual es el mismo modelo de generación de datos, por lo que
# la serie intervenida también exhibiría esta tendencia 'natural' que se combina con el efecto de la
# intervención

sal_min = 3
iniciales = 240
per_inter = iniciales + 120 + 1
total = per_inter + 120
simular(total, 'no-activada', 'bajo', per_inter, coto= 20, ana_sen=0)
print('Media de la desocupación periodo inicial=', np.mean(des_temp[iniciales+1:per_inter]))
print('Media de la desocupación periodo final=', np.mean(des_temp[per_inter:total]))
print('Media de la diferencia en desocupación=', np.mean(des_temp[per_inter:total])- np.mean(des_temp[iniciales+1:per_inter]))
# Out:
# Media de la desocupación periodo inicial= 13.391666666666667
# Media de la desocupación periodo final= 15.533333333333333
# Media de la diferencia en desocupación= 2.1416666666666657

# %%
#Rutina de graficación para mostrar dinámica de desempleo sin intervención


des_temp_inicio = des_temp[iniciales+1:per_inter]
des_temp_final = des_temp[per_inter:total]
plt.plot(des_temp_inicio, label = "inicio de la muestra")
plt.plot(des_temp_final, label = "final de la muestra")
plt.xlabel('Tiempo')
plt.ylabel('Desempleo')
plt.suptitle("Dinámica del desempleo en los dos periodos de la muestra")
plt.title('(sin intervención)')
plt.legend()
plt.show()

# %% [markdown]
# El propósito de esta grafica es mostrar que, en este modelo, cuando no hay intervención (incremento en los salarios mínimos) el subperiodo final de la corrida(linea naranja) muestra niveles de desempleo similares a los del subperiodo inicial (línea azul).
# Este resultado es indicativo de un proceso generador de datos en donde el desempleo tiende a
# mantenerse constante

# %%
# Simulaciones de Monte Carlo en las que se corre el modelo N número de veces  


Dif_medias_pos = [] #listado para guardar los promedios de las diferencias mensuales post-intervención
Medias_pre = [] # Listado para guardar promedios del desempleo pre-intervención
batch_dif = []  # listado para incorporar las diferencias mensuales post-intervención de cada corrida
for j in range(0,150):
    print('iteración número =', j+1)
    sal_min = 3
    iniciales = 240
    per_inter = iniciales + 120 + 1
    total = per_inter + 120 
    dif_post_int = []      # listado para ir guardando las diferencias mensuales post-intervención
    simular(total, 'no_activada', 'bajo', per_inter, coto= 20, ana_sen=0)
    des_temp_noact = des_temp
    simular(total, 'activada', 'bajo', per_inter, coto=20, ana_sen=0)
    des_temp_act = des_temp
    for item1, item2 in zip(des_temp_act[per_inter:total], des_temp_noact[per_inter:total]):
        item = item1 - item2
        dif_post_int.append(item)
    #print('Media de la diferencia de desocupación post-intervención =', np.mean(dif_post_int))
    Dif_medias_pos.append(np.mean(dif_post_int)) # se calculo el promedio del desempleo generado
                                                 # en periodo postintervención en serie intervenida
                                                 # mensual (diferencias versus contrafactual)
    Medias_pre.append(np.mean(des_temp_act[iniciales+1:per_inter])) # Promedio mensual del desempleo
                                                                    # pre-intervención
    batch_dif.append(dif_post_int)                # creo una lista de listas, en la que cada una
                                                  # describe la dinamica en el tiempo de 
                                                  # las intervenciones
# Out:
# iteración número = 1
# Salario mínimo post-intervención = 5.197042306712569
# iteración número = 2
# Salario mínimo post-intervención = 5.195481474751347
# iteración número = 3
# Salario mínimo post-intervención = 5.179512004349615
# iteración número = 4
# Salario mínimo post-intervención = 5.183389510437308
# iteración número = 5
# Salario mínimo post-intervención = 5.184141189302279
# iteración número = 6
# Salario mínimo post-intervención = 5.194909594240659
# iteración número = 7
# Salario mínimo post-intervención = 5.198222014039477
# iteración número = 8
# Salario mínimo post-intervención = 5.201767008921341
# iteración número = 9
# Salario mínimo post-intervención = 5.195261903684093
# iteración número = 10
# Salario mínimo post-intervención = 5.1941130238347775
# iteración número = 11
# Salario mínimo post-intervención = 5.209300106107793
# iteración número = 12
# Salario mínimo post-intervención = 5.204911672526707
# iteración número = 13
# Salario mínimo post-intervención = 5.216923004313852
# iteración número = 14
# Salario mínimo post-intervención = 5.197975072472332
# iteración número = 15
# Salario mínimo post-intervención = 5.215363346338284
# iteración número = 16
# Salario mínimo post-intervención = 5.195629653377406
# iteración número = 17
# Salario mínimo post-intervención = 5.193423219087589
# iteración número = 18
# Salario mínimo post-intervención = 5.195511506991599
# iteración número = 19
# Salario mínimo post-intervención = 5.187194099667725
# iteración número = 20
# Salario mínimo post-intervención = 5.199091814941733
# iteración número = 21
# Salario mínimo post-intervención = 5.186122367529957
# iteración número = 22
# Salario mínimo post-intervención = 5.197698941289486
# iteración número = 23
# Salario mínimo post-intervención = 5.213060122284917
# iteración número = 24
# Salario mínimo post-intervención = 5.1817442157200695
# iteración número = 25
# Salario mínimo post-intervención = 5.223395011324898
# iteración número = 26
# Salario mínimo post-intervención = 5.252841484635171
# iteración número = 27
# Salario mínimo post-intervención = 5.26804886361659
# iteración número = 28
# Salario mínimo post-intervención = 5.1842380323696355
# iteración número = 29
# Salario mínimo post-intervención = 5.198790268890836
# iteración número = 30
# Salario mínimo post-intervención = 5.183787075246893
# iteración número = 31
# Salario mínimo post-intervención = 5.188740234508056
# iteración número = 32
# Salario mínimo post-intervención = 5.187168370573197
# iteración número = 33
# Salario mínimo post-intervención = 5.187718772692511
# iteración número = 34
# Salario mínimo post-intervención = 5.22816523871808
# iteración número = 35
# Salario mínimo post-intervención = 5.188800046212728
# iteración número = 36
# Salario mínimo post-intervención = 5.214625018460211
# iteración número = 37
# Salario mínimo post-intervención = 5.194225713281326
# iteración número = 38
# Salario mínimo post-intervención = 5.177515463042141
# iteración número = 39
# Salario mínimo post-intervención = 5.179306856179821
# iteración número = 40
# Salario mínimo post-intervención = 5.195734247491161
# iteración número = 41
# Salario mínimo post-intervención = 5.252764599416533
# iteración número = 42
# Salario mínimo post-intervención = 5.235844733045497
# iteración número = 43
# Salario mínimo post-intervención = 5.193461102230067
# iteración número = 44
# Salario mínimo post-intervención = 5.2108415734672135
# iteración número = 45
# Salario mínimo post-intervención = 5.185316215010896
# iteración número = 46
# Salario mínimo post-intervención = 5.1972964685926
# iteración número = 47
# Salario mínimo post-intervención = 5.209636806062773
# iteración número = 48
# Salario mínimo post-intervención = 5.196328874153373
# iteración número = 49
# Salario mínimo post-intervención = 5.1858668409451045
# iteración número = 50
# Salario mínimo post-intervención = 5.190308262083251
# iteración número = 51
# Salario mínimo post-intervención = 5.192809420721073
# iteración número = 52
# Salario mínimo post-intervención = 5.181588423435449
# iteración número = 53
# Salario mínimo post-intervención = 5.2380180933907985
# iteración número = 54
# Salario mínimo post-intervención = 5.207031924158279
# iteración número = 55
# Salario mínimo post-intervención = 5.217831254236007
# iteración número = 56
# Salario mínimo post-intervención = 5.171947659014446
# iteración número = 57
# Salario mínimo post-intervención = 5.199570344661073
# iteración número = 58
# Salario mínimo post-intervención = 5.181963907661415
# iteración número = 59
# Salario mínimo post-intervención = 5.214779875486064
# iteración número = 60
# Salario mínimo post-intervención = 5.203025837723041
# iteración número = 61
# Salario mínimo post-intervención = 5.19480640630883
# iteración número = 62
# Salario mínimo post-intervención = 5.2299067611540035
# iteración número = 63
# Salario mínimo post-intervención = 5.193863489701125
# iteración número = 64
# Salario mínimo post-intervención = 5.19698882860479
# iteración número = 65
# Salario mínimo post-intervención = 5.236461892952907
# iteración número = 66
# Salario mínimo post-intervención = 5.189680996307914
# iteración número = 67
# Salario mínimo post-intervención = 5.197671590187935
# iteración número = 68
# Salario mínimo post-intervención = 5.5092878822716935
# iteración número = 69
# Salario mínimo post-intervención = 5.186444978798624
# iteración número = 70
# Salario mínimo post-intervención = 5.1823976132947
# iteración número = 71
# Salario mínimo post-intervención = 5.188134446344214
# iteración número = 72
# Salario mínimo post-intervención = 5.1924642357046675
# iteración número = 73
# Salario mínimo post-intervención = 5.187374148608894
# iteración número = 74
# Salario mínimo post-intervención = 5.196791849353071
# iteración número = 75
# Salario mínimo post-intervención = 5.235406893128934
# iteración número = 76
# Salario mínimo post-intervención = 5.199275900148243
# iteración número = 77
# Salario mínimo post-intervención = 5.193479528810839
# iteración número = 78
# Salario mínimo post-intervención = 5.182365997495855
# iteración número = 79
# Salario mínimo post-intervención = 5.200040010410799
# iteración número = 80
# Salario mínimo post-intervención = 5.209323129071999
# iteración número = 81
# Salario mínimo post-intervención = 5.181056819764845
# iteración número = 82
# Salario mínimo post-intervención = 5.1953215796339665
# iteración número = 83
# Salario mínimo post-intervención = 5.215322713606347
# iteración número = 84
# Salario mínimo post-intervención = 5.194907775199336
# iteración número = 85
# Salario mínimo post-intervención = 5.1826970736657
# iteración número = 86
# Salario mínimo post-intervención = 5.193044178544939
# iteración número = 87
# Salario mínimo post-intervención = 5.184393680949373
# iteración número = 88
# Salario mínimo post-intervención = 5.177037491637567
# iteración número = 89
# Salario mínimo post-intervención = 5.201976236409529
# iteración número = 90
# Salario mínimo post-intervención = 5.2062109264556735
# iteración número = 91
# Salario mínimo post-intervención = 5.209492282681738
# iteración número = 92
# Salario mínimo post-intervención = 5.194448421110107
# iteración número = 93
# Salario mínimo post-intervención = 5.199267192594717
# iteración número = 94
# Salario mínimo post-intervención = 5.170201272252227
# iteración número = 95
# Salario mínimo post-intervención = 5.2549054624444045
# iteración número = 96
# Salario mínimo post-intervención = 5.182368510179982
# iteración número = 97
# Salario mínimo post-intervención = 5.178406545165487
# iteración número = 98
# Salario mínimo post-intervención = 5.194827553869998
# iteración número = 99
# Salario mínimo post-intervención = 5.198989606083045
# iteración número = 100
# Salario mínimo post-intervención = 5.457061990734409
# iteración número = 101
# Salario mínimo post-intervención = 5.188493699295926
# iteración número = 102
# Salario mínimo post-intervención = 5.219853215905072
# iteración número = 103
# Salario mínimo post-intervención = 5.199511514562759
# iteración número = 104
# Salario mínimo post-intervención = 5.181718863729642
# iteración número = 105
# Salario mínimo post-intervención = 5.1918000470244134
# iteración número = 106
# Salario mínimo post-intervención = 5.1952450209019725
# iteración número = 107
# Salario mínimo post-intervención = 5.208999465499273
# iteración número = 108
# Salario mínimo post-intervención = 5.183104912631941
# iteración número = 109
# Salario mínimo post-intervención = 5.1987705177165076
# iteración número = 110
# Salario mínimo post-intervención = 5.179879804501986
# iteración número = 111
# Salario mínimo post-intervención = 5.2300351632470345
# iteración número = 112
# Salario mínimo post-intervención = 5.187464951496852
# iteración número = 113
# Salario mínimo post-intervención = 5.205307140003281
# iteración número = 114
# Salario mínimo post-intervención = 5.183264393880058
# iteración número = 115
# Salario mínimo post-intervención = 5.19705461423905
# iteración número = 116
# Salario mínimo post-intervención = 5.266975383446068
# iteración número = 117
# Salario mínimo post-intervención = 5.1953527336211165
# iteración número = 118
# Salario mínimo post-intervención = 5.1955199815466555
# iteración número = 119
# Salario mínimo post-intervención = 5.204103177450513
# iteración número = 120
# Salario mínimo post-intervención = 5.317837478244268
# iteración número = 121
# Salario mínimo post-intervención = 5.199005501200328
# iteración número = 122
# Salario mínimo post-intervención = 5.193107480952741
# iteración número = 123
# Salario mínimo post-intervención = 5.19847385995488
# iteración número = 124
# Salario mínimo post-intervención = 5.192423661909062
# iteración número = 125
# Salario mínimo post-intervención = 5.185336848143916
# iteración número = 126
# Salario mínimo post-intervención = 5.192778049032603
# iteración número = 127
# Salario mínimo post-intervención = 5.186677688118193
# iteración número = 128
# Salario mínimo post-intervención = 5.184852855949035
# iteración número = 129
# Salario mínimo post-intervención = 5.190307365202591
# iteración número = 130
# Salario mínimo post-intervención = 5.276218613135741
# iteración número = 131
# Salario mínimo post-intervención = 5.179128513500647
# iteración número = 132
# Salario mínimo post-intervención = 5.17872957593063
# iteración número = 133
# Salario mínimo post-intervención = 5.200118075558452
# iteración número = 134
# Salario mínimo post-intervención = 5.172988963987632
# iteración número = 135
# Salario mínimo post-intervención = 5.184400973722373
# iteración número = 136
# Salario mínimo post-intervención = 5.219685540080279
# iteración número = 137
# Salario mínimo post-intervención = 5.183236433507494
# iteración número = 138
# Salario mínimo post-intervención = 5.189325927743569
# iteración número = 139
# Salario mínimo post-intervención = 5.199349055374781
# iteración número = 140
# Salario mínimo post-intervención = 5.190883548040336
# iteración número = 141
# Salario mínimo post-intervención = 5.234045314202326
# iteración número = 142
# Salario mínimo post-intervención = 5.1889431511140005
# iteración número = 143
# Salario mínimo post-intervención = 5.211366683104189
# iteración número = 144
# Salario mínimo post-intervención = 5.196425318621229
# iteración número = 145
# Salario mínimo post-intervención = 5.1822550013644495
# iteración número = 146
# Salario mínimo post-intervención = 5.188426367693155
# iteración número = 147
# Salario mínimo post-intervención = 5.180499900554389
# iteración número = 148
# Salario mínimo post-intervención = 5.17336902298104
# iteración número = 149
# Salario mínimo post-intervención = 5.206972684922114
# iteración número = 150
# Salario mínimo post-intervención = 5.214536813068685

# %%
# Histogramas en que se muestran las estimaciones de los promedios de las diferencias mensuales
# en el desempleo post-intervención para las N simulaciones de Monte Carlo

plt.hist(Dif_medias_pos, bins=20, edgecolor='black')
plt.xlabel('Estimación de impactos')
plt.ylabel('Frecuencia')
plt.title("(a partir de medias)")
plt.suptitle("Distribución de los promedios del desempleo estimados")
plt.show()
print('Impacto medio en el desempleo =', np.mean(Dif_medias_pos))
a = (np.mean(Dif_medias_pos)/np.mean(Medias_pre))*100
print('Impacto medio en el desempleo en relación al contrafactual=', a, '%')

# Con esta gráfica se visualizan las series de diferencias mensuales post-intervención que se 
# con las distintas corridas de Monte Carlo 

for i in batch_dif:
    plt.plot(i)
plt.xlabel('Mes')
plt.ylabel('Estimación')
plt.title("Series de impactos mensuales")
plt.axhline(y = 0, color = 'r', linestyle='dashed', label = 'mes de la intervención')
# Out:
# Impacto medio en el desempleo = -6.573944444444445
# Impacto medio en el desempleo en relación al contrafactual= -43.469683889572586 %

# %% [markdown]
# Exlicación histograma: Notar que todos los impactos son negativos; es decir, hubo una reducción del desempleo. El desempleo medio bajo en 22 unidades, en el promedio de las corridas de Monte Carlo; cifra que comparada con el desempleo promedio pre-intervención significa una caida del 39.7%
# La ventaja de obtener estas distribuciones es que sabemos el grado estadístico de significancia;
# es decir, la probabilidad de la hipótesis nula de no significancia del impacto es del 0%
#
# Explicación series de diferencias de las medias de desempleo postratamiento:
# Notar que en todas las corridas hubo un rápido decremento del
# desempleo, patrón que se sostuvo así para muchas corridas durante los 120 meses post-intervención.
# Notar que hay una relación no-lineal en el tiempo, en donde al inicio va bajando
# gradualmente el desempleo y por ahí del mes 25 la situación se revierte, llegando inclusive en algunas corridas a generarse  mayor desempleo

# %%
# El propósito de esta rutina es modificar la función (intervenir) para realizar análisis de
# sensibilidad y así checar el impacto que tiene el alza en salarios mínimos sobre el
# desempleo medido usando el criterio de estimación de diferencias post-tratamiento

def intervenir(incr_sal, ana_sen):  # incr_sal define el tipo de incremento entre bajo, medio y alto
    global factibles, sal_conv
    mean_conv = sal_conv[vacantes == 1].mean()  # se toma la media de los salarios convencionales
    sal_min = mean_conv*(0.7+ana_sen)           # se generan incrementos paulatinos en los salarios                                    # mínimos
    print('Salario mínimo post-intervención =', sal_min)
    return sal_min

# %%
# En esta rutina se lleva a cabo el análisis de sensibilidad del incremento en salarios mínimos de
# distinta magnitud, en los primeros casos se trata de alzas marginales en las que los salarios 
# mínimos se incrementan por debajo de los convencionales del periodo pre-intervención
# Los siguientes escenarios corresponden a escenarios bajos en los que el salario supera a los
# convencionales, pero no lo suficiente para exceder la capacidad de pago de los hogares
# El el úntimo escenario, cada vez más hogares empiezan a observar salarios mínimos que exceden sus 
# capacidades financieras

Dif_sens = []
ana_sen = 0
for k in range (0, 60):
    sal_min = 3                    
    iniciales = 240
    per_inter = iniciales + 120 + 1
    total = per_inter + 120
    simular(total, 'no_activada', 'bajo', per_inter, 20, ana_sen)  # en esta corrida no hay intervención
    des_temp_noact = des_temp               # listado con datos de desempleo para serie contrafactual
                                        # es decir, sin la intervención
    simular(total, 'activada', 'bajo', per_inter, 20, ana_sen)  # en esta corrida si hay intervención   
    des_temp_act = des_temp                 # listado con datos de desempleo c/intervención      
    dif_post_int = []                      # Listado para primeras diferencias con datos de c/mes
                                       # en el periodo post-intervención
    for item1, item2 in zip(des_temp_act[per_inter:total], des_temp_noact[per_inter:total]):
        item = item1 - item2
        dif_post_int.append(item)      # se van agregando diferencias en pre-intervención
                                       # se imprimen datos de las primeras diferencias:
    #print('Media de la diferencia de desocupación post-intervención =', np.mean(dif_post_int))
                                      
    Dif_sens.append(np.mean(dif_post_int))   # Se saca el promedio de las diferencias
                                                   # mensuales del desempleo (vs contrafactual)
                                                   # y se van agregando al listado de promedios
                                                   # por corrida
    ana_sen += 0.2
# Out:
# Salario mínimo post-intervención = 2.4253457937966174
# Salario mínimo post-intervención = 3.1162769353664674
# Salario mínimo post-intervención = 3.8019255467075035
# Salario mínimo post-intervención = 4.517721657857759
# Salario mínimo post-intervención = 5.200445140616647
# Salario mínimo post-intervención = 5.8857976949995425
# Salario mínimo post-intervención = 6.599429854120913
# Salario mínimo post-intervención = 7.2876979674524005
# Salario mínimo post-intervención = 7.959188074750988
# Salario mínimo post-intervención = 8.802751542132489
# Salario mínimo post-intervención = 9.43791082753653
# Salario mínimo post-intervención = 10.096617153177082
# Salario mínimo post-intervención = 10.769348305267737
# Salario mínimo post-intervención = 11.374513126723084
# Salario mínimo post-intervención = 12.121459706175104
# Salario mínimo post-intervención = 12.844134941658579
# Salario mínimo post-intervención = 13.516200207125356
# Salario mínimo post-intervención = 14.20772625200949
# Salario mínimo post-intervención = 15.001259192949815
# Salario mínimo post-intervención = 15.551662955575642
# Salario mínimo post-intervención = 16.2514997886868
# Salario mínimo post-intervención = 16.91540688292403
# Salario mínimo post-intervención = 17.65140585016081
# Salario mínimo post-intervención = 18.356900619921376
# Salario mínimo post-intervención = 19.00721617022481
# Salario mínimo post-intervención = 19.6743996631751
# Salario mínimo post-intervención = 20.445934594158313
# Salario mínimo post-intervención = 21.213819632115264
# Salario mínimo post-intervención = 21.787304660875204
# Salario mínimo post-intervención = 22.514858741254102
# Salario mínimo post-intervención = 23.103402257409687
# Salario mínimo post-intervención = 23.803158481038743
# Salario mínimo post-intervención = 24.506668642363383
# Salario mínimo post-intervención = 25.2185361904414
# Salario mínimo post-intervención = 25.920278209191615
# Salario mínimo post-intervención = 26.608886704898822
# Salario mínimo post-intervención = 27.49587538858844
# Salario mínimo post-intervención = 28.130615490781217
# Salario mínimo post-intervención = 28.963903650918812
# Salario mínimo post-intervención = 29.511404281075205
# Salario mínimo post-intervención = 30.103850248999006
# Salario mínimo post-intervención = 30.805581935566686
# Salario mínimo post-intervención = 31.596092901649463
# Salario mínimo post-intervención = 32.074223450073426
# Salario mínimo post-intervención = 32.99344771060294
# Salario mínimo post-intervención = 33.66262360222644
# Salario mínimo post-intervención = 34.207359565636295
# Salario mínimo post-intervención = 34.88420364555223
# Salario mínimo post-intervención = 35.652502234751566
# Salario mínimo post-intervención = 36.35030019430703
# Salario mínimo post-intervención = 37.09690248305093
# Salario mínimo post-intervención = 37.71840380264906
# Salario mínimo post-intervención = 38.340293014328815
# Salario mínimo post-intervención = 39.1921689057964
# Salario mínimo post-intervención = 39.78382901869751
# Salario mínimo post-intervención = 40.43328671656328
# Salario mínimo post-intervención = 41.132351457289296
# Salario mínimo post-intervención = 41.87790688947274
# Salario mínimo post-intervención = 42.6882621689595
# Salario mínimo post-intervención = 43.28476727623356

# %%
# En esta rutina se grafica la evolución de las estimaciones en diferencias post-interveción
# para promedios del desempleo a partir de análisis de sensibilidad con alzas crecientes 
# en los salarios mínimos

print('vector de impactos estimados para distintos niveles de alzas en salarios mínimos =', Dif_sens)
analisis = list(range(1, len(Dif_sens)+1))
plt.plot(analisis, Dif_sens, label = "Medias estimadas")
plt.axhline(y = 0, color = 'b', linestyle='dashed', label = 'umbral del impacto')
plt.xlabel('Número de análisis')
plt.ylabel('Estimaciones del impacto')
plt.suptitle("Variaciones en el impacto sobre el desempleo")
plt.title('(Análisis de sensibilidad ante cambios en salarios mínimos de distinta magnitud)')
plt.legend()
plt.show()
# Out:
# vector de impactos estimados para distintos niveles de alzas en salarios mínimos = [0.03333333333333333, -0.7083333333333334, -3.9, -6.0, -6.35, -7.233333333333333, -5.833333333333333, -6.891666666666667, -6.891666666666667, -7.683333333333334, -8.675, -7.741666666666666, -8.175, -7.591666666666667, -6.991666666666666, -7.025, -7.0, -7.25, -7.008333333333334, -8.341666666666667, -8.216666666666667, -6.958333333333333, -7.866666666666666, -7.458333333333333, -7.366666666666666, -7.691666666666666, -8.925, -6.558333333333334, -7.416666666666667, -6.85, -7.916666666666667, -8.266666666666667, -9.0, -7.8, -7.316666666666666, -7.158333333333333, -6.033333333333333, -7.433333333333334, -8.241666666666667, -7.608333333333333, -8.7, -7.958333333333333, -5.383333333333334, -8.008333333333333, -7.85, -8.25, -6.133333333333334, -7.275, -5.775, -4.733333333333333, -4.516666666666667, -4.483333333333333, -4.116666666666666, -4.15, -3.75, -0.9166666666666666, -0.2916666666666667, 0.075, 3.533333333333333, 6.183333333333334]

# %% [markdown]
# En este análisis de sensibilidad se observa que para un amplio margen de incrementos en salarios
# mínimos se produce una reducción del desempleo medio (promedio de los meses) post-intervención.
# Sin embargo, llega un punto en que muchos hogares se ven afectados por la imposibilidad de pagar
# salarios tan altos ya que compromete su situación financiera, por lo que el impacto se revierte
# y se observa un aumento en el desempleo.

# %%
# En esta rutina se presenta un análisis de sensibilidad en el que se generan 17 cotos diferentes, los
# cuales varían en función de la capacidad de los hogares  para generar ingresos con los que 
# pagar salarios

Dif_sens = []
coto = 4
for k in range (0, 40):
    sal_min = 3                    
    iniciales = 240
    per_inter = iniciales + 120 + 1
    total = per_inter + 120
    simular(total, 'no_activada', 'bajo', per_inter, coto, ana_sen=8)  # en esta corrida no hay
                                            # intervención.  
    des_temp_noact = des_temp               # listado con datos de desempleo para serie contrafactual
                                            # es decir, sin la intervención
    simular(total, 'activada', 'bajo', per_inter, coto, ana_sen=8)  # en esta corrida si hay 
                                                                      # intervención
                                            # Notar se considera que el aumento en sal_min es fijo
    des_temp_act = des_temp                 # listado con datos de desempleo c/intervención      
    dif_post_int = []                      # Listado para diferencias con datos de c/mes
                                           # en el periodo post-intervención
    for item1, item2 in zip(des_temp_act[per_inter:total], des_temp_noact[per_inter:total]):
        item = item1 - item2
        dif_post_int.append(item)      # se van agregando diferencias en pre-intervención
                                       # se imprimen datos de las primeras diferencias:
    #print('Media de la diferencia de desocupación post-intervención =', np.mean(dif_post_int))
                                       # se imprimen datos de las segundas diferencias
    Dif_sens.append(np.mean(dif_post_int))   # Se saca el promedio de las diferencias
                                                   # mensuales del desempleo (vs contrafactual)
                                                   # y se van agregando al listado de promedios
                                                   # por corrida
    coto += 1
# Out:
# Salario mínimo post-intervención = 30.119522650304255
# Salario mínimo post-intervención = 30.087876164457644
# Salario mínimo post-intervención = 30.085891637305057
# Salario mínimo post-intervención = 30.09892822531988
# Salario mínimo post-intervención = 30.2507723787045
# Salario mínimo post-intervención = 30.13265273866203
# Salario mínimo post-intervención = 30.331211250241637
# Salario mínimo post-intervención = 30.31476066465816
# Salario mínimo post-intervención = 30.125259328185795
# Salario mínimo post-intervención = 30.09326992804947
# Salario mínimo post-intervención = 30.08754635455824
# Salario mínimo post-intervención = 30.113965069802664
# Salario mínimo post-intervención = 30.039421681147264
# Salario mínimo post-intervención = 30.057507392176383
# Salario mínimo post-intervención = 30.042634140207195
# Salario mínimo post-intervención = 30.129109149568354
# Salario mínimo post-intervención = 30.080856501338367
# Salario mínimo post-intervención = 30.067235734245767
# Salario mínimo post-intervención = 30.141113056197913
# Salario mínimo post-intervención = 30.138793608815718
# Salario mínimo post-intervención = 30.065389264315566
# Salario mínimo post-intervención = 30.206528670226128
# Salario mínimo post-intervención = 30.146565007783202
# Salario mínimo post-intervención = 30.126299487724594
# Salario mínimo post-intervención = 30.128338221859803
# Salario mínimo post-intervención = 30.09284020104423
# Salario mínimo post-intervención = 30.15171932201539
# Salario mínimo post-intervención = 30.1231087726209
# Salario mínimo post-intervención = 30.031791270783334
# Salario mínimo post-intervención = 30.140698014082165
# Salario mínimo post-intervención = 30.08639062871169
# Salario mínimo post-intervención = 30.1201518724578
# Salario mínimo post-intervención = 30.143501654647874
# Salario mínimo post-intervención = 30.550779201162335
# Salario mínimo post-intervención = 30.2036831913924
# Salario mínimo post-intervención = 30.093673609057017
# Salario mínimo post-intervención = 30.33575780338488
# Salario mínimo post-intervención = 30.09236563827378
# Salario mínimo post-intervención = 30.12876464060087
# Salario mínimo post-intervención = 30.135610141877084

# %%
# En esta rutina se grafica la evolución de las estimaciones de las diferencias
# post-intervención del desempleo (promedios de diferencias mensuales)
# a partir de alzas crecientes en la capacidad de pago de los hogares de 17 cotos

print('vector de estimaciones de impacto para cotos con distintas capacidades de pago =', Dif_sens)
analisis = list(range(1, len(Dif_sens)+1))
plt.plot(analisis, Dif_sens, label = "DiD de medias estimado")
plt.axhline(y = 0, color = 'b', linestyle='dashed', label = 'umbral del impacto')
plt.xlabel('Número de análisis')
plt.ylabel('Impactos')
plt.suptitle("Cotos de distinta naturaleza dependiendo de su capacidad de pago")
plt.title('(Análisis de sensibilidad: de menor a mayor)')
plt.legend()
plt.show()
# Out:
# vector de estimaciones de impacto para cotos con distintas capacidades de pago = [25.3, 15.241666666666667, 10.633333333333333, 5.633333333333334, 6.491666666666666, 1.0416666666666667, -0.25, -1.6583333333333334, -3.125, -5.0, -4.45, -5.708333333333333, -4.45, -6.925, -6.45, -6.666666666666667, -5.558333333333334, -6.583333333333333, -7.375, -6.908333333333333, -7.4, -7.991666666666666, -7.325, -6.491666666666666, -6.808333333333334, -7.766666666666667, -8.308333333333334, -8.241666666666667, -7.658333333333333, -7.816666666666666, -8.258333333333333, -9.666666666666666, -8.9, -8.583333333333334, -7.75, -7.7, -8.141666666666667, -7.85, -9.316666666666666, -8.841666666666667]

# %% [markdown]
# Este análisis muestra que si se toman unidades de análisis que discrepan en un factor fundamental, en
# este caso capacidad de pago de los hogares, un mismo incremento en salarios mínimos va a producir resultados muy diferente en el impacto sobre el desempleo. Por ello este tipo de pooling en un
# modelo econométrico de DiDs va a genarar un resutado promedio que no es representativo de las unidades analizadas
# En las primeras simulaciones, el nivel de ingresos de los hogares es relativamente bajo, por lo que para un incremento en salarios mínimos elevados se produce un aumento en el desempleo.  Conforme va
# incrementandose este ingreso de los hogares va cayendo el impacto del desempleo. Pasando un cierto umbral, en el que los ingresos son relativamente altos, el mismo ejercició produce decrementos en el
# desempleo.

# %%
# Esta rutina no la usamos, pero sería otra forma de actualizar salarios pagados
# si los ajustes se hacen exclusivamente en los hogares en donde se ubican las trabajoras sin empleo.

#for i in rompen + ind2:      # se itera sobre las empleadas sin chamba sin importar la razón
#    x = empleadas[i][0]                 # se especifican sus coordenadas en el empleo previo
#    y = empleadas[i][1]
#    for dx in range(-1, 2):             # se itera sobre la vecinadad (tipo Moore)
#       for dy in range(-1, 2):
                                            # se ajusta el salario convencional tomando la suma
                                            # del propio y de los vecinos en el periodo previo
                                            # notar que se toman fronteras periódicas
                            
#           sal_conv[x,y] += ant_sal[(x + dx) % base, (y+dy) % altura]
#           sal_conv[x,y] = sal_conv[x,y]/9     # se saca el promedio
                                            # notar que los hogares solo ajustan
                                            # el salario cuando ya no existe relación contractual
